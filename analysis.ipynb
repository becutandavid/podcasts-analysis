# %%
import pandas as pd
import numpy as np

# %%
podcasts = pd.read_pickle('data/xaa_podcasts.pkl')
episodes = pd.read_pickle('data/xaa_episodes.pkl')

# %%
def get_episodes(x: pd.Series):
    """helper function for getting episodes from data. Mainly used as a lambda function

    Args:
        x (pd.Series): row of dataframe

    Returns:
        _type_: _description_
    """
    id = x['databaseId']
    df = pd.DataFrame(x['scraped']['episodes'])
    df['podcastId'] = id
    return df

def split_data(df: pd.DataFrame) -> tuple[pd.DataFrame, pd.DataFrame]:
    """split data into podcasts and episodes

    Args:
        df (pd.DataFrame): loaded df chunk

    Returns:
        tuple[pd.DataFrame, pd.DataFrame]: podcasts, episodes
    """
    podcasts = df.apply(lambda x: pd.Series(x['scraped']['meta']), axis=1)
    podcasts['id'] = df['databaseId']
    
    episodes = df.apply(get_episodes, axis=1)
    
    return podcasts, episodes
    
def filter_podcasts(podcasts: pd.DataFrame) -> pd.DataFrame:
    """filter podcasts and drop columns

    Args:
        podcasts (pd.DataFrame): podcasts dataframe

    Returns:
        pd.DataFrame: filtered podcasts dataframe
    """
    value_counts = (podcasts.isna().sum() / podcasts.shape[0]).sort_values()
    podcasts.drop(columns=value_counts[value_counts > 0.9].index, inplace=True)
    podcasts.drop(columns=['type', 'funding'], inplace=True, errors='ignore')
    podcasts['explicit'] = podcasts['explicit'].astype(bool)
    
    return podcasts

from datetime import datetime
def timezone_map(x):
    try:
        x = " ".join(x.split(' ')[:4]) # remove timestamp, keep only date
        date_format = "%a, %d %b %Y"
        return datetime.strptime(x, date_format)
    except:
        return None

def filter_episodes(episodes: pd.DataFrame) -> pd.DataFrame:
    """filter episodes and drop columns

    Args:
        episodes (pd.DataFrame): episodes dataframe

    Returns:
        pd.DataFrame: filtered episodes dataframe
    """
    value_counts = (episodes.isna().sum() / episodes.shape[0]).sort_values()
    episodes.drop(columns=value_counts[value_counts > 0.9].index, inplace=True)
    episodes.drop(columns=['funding', 'transcript', 'soundbite'], inplace=True, errors='ignore')
    episodes['explicit'] = episodes['explicit'].astype(bool)
    
    episodes['pubDate'] = episodes.pubDate.map(timezone_map)
    
    return episodes

# %%
df = pd.read_json('data/xan', lines=True)

# %%
podcasts = df.apply(lambda x: pd.Series(x['scraped']['meta']), axis=1)

# %%
podcasts['id'] = df['databaseId']

# %%
pd.DataFrame(df.iloc[0][0]['episodes'])
# Out:
#                                                 title  \
# 0   después de odio en redes sociales, Ciomar a Ca...
# 1   Resumen deportivo correspondiente al 23 de nov...
# 2   ¿Realmente Apple hace historia con sus nuevos ...
# 3               Podcast deportivo 17 de enero de 2022
# 4                   Analizando las zedes en Honduras
# 5   Propuestas electorales en Honduras, conócelas ...
# 6                               EL ANÁLISIS (Trailer)
# 7                   un resumen deportivo interesante
# 8   Sección deportiva correspondiente al 22 de oct...
# 9   sección deportiva correspondiente al 15 de ene...
# 10  Podcast deportivo correspondiente al 25 de oct...
# 11  Sección deportiva correspondiente al 18 de oct...
# 12                                   Feliz Año Nuevo.
# 13  Podcast deportivo correspondiente al 29 de oct...
# 14                      Recuento deportivo número uno
# 15  Hablemos de ómicron y la situación actual de l...
#
#                                           description  duration  \
# 0   Hola a todos. En este episodio, David Mendoza ...      1518
# 1   En este episodio, Fabricio Ponce nos trae la e...       401
# 2   En este episodio, Tito Valle y David Mendoza, ...      1452
# 3   En este episodio, Fabricio Ponce nos actualiza...       576
# 4   Qué tal oyentes del podcast EL ANÁLISIS. En es...      2350
# 5   <p>en este episodio, David Mendoza, Fabricio P...      1967
# 6                                                 NaN        25
# 7   <p>en este episodio, el compañero Fabricio Pon...      1529
# 8   En este episodio, Fabricio Ponce nos hace un e...      1046
# 9   en este episodio, Fabricio Ponce nos habla de ...       615
# 10  En este episodio, Fabricio Ponce “como ya nos ...      1200
# 11  Hoy, Fabricio Ponce nos trae los resultados de...       748
# 12  En este episodio un poco más informal, hablare...      2209
# 13  En este episodio, Fabricio Ponce nos habla de ...       897
# 14  En este episodio, Fabricio ponse nos trae un e...       484
# 15  en este primer episodio del 2022 analizamos la...      1539
#
#                                             enclosure  explicit funding  \
# 0   {'length': '24563220', 'type': 'audio/x-m4a', ...     False      []
# 1   {'length': '6501499', 'type': 'audio/x-m4a', '...     False      []
# 2   {'length': '23491678', 'type': 'audio/x-m4a', ...     False      []
# 3   {'length': '9321321', 'type': 'audio/x-m4a', '...     False      []
# 4   {'length': '38020511', 'type': 'audio/x-m4a', ...     False      []
# 5   {'length': '31826009', 'type': 'audio/x-m4a', ...     False      []
# 6   {'length': '410594', 'type': 'audio/x-m4a', 'u...     False      []
# 7   {'length': '24744402', 'type': 'audio/x-m4a', ...     False      []
# 8   {'length': '16932346', 'type': 'audio/x-m4a', ...     False      []
# 9   {'length': '9956668', 'type': 'audio/x-m4a', '...     False      []
# 10  {'length': '19415328', 'type': 'audio/x-m4a', ...     False      []
# 11  {'length': '12100957', 'type': 'audio/x-m4a', ...     False      []
# 12  {'length': '35733626', 'type': 'audio/x-m4a', ...     False      []
# 13  {'length': '14509899', 'type': 'audio/x-m4a', ...     False      []
# 14  {'length': '7829340', 'type': 'audio/x-m4a', '...     False      []
# 15  {'length': '24897605', 'type': 'audio/x-m4a', ...     False      []
#
#                                     guid  \
# 0   5a3c6e00-33e4-4811-b7eb-d0b6c7644a32
# 1   d8368585-78a2-48b2-94e1-10ba78e70ebe
# 2   077fb77b-e75c-439b-8982-8c271c137aca
# 3   75fd6db8-bd56-4620-9d81-a9932171c95f
# 4   f7a04554-8466-40a6-8303-2e8b6be056a3
# 5   a33228b9-949e-4255-9b6b-93eaa3af7f11
# 6   a4dba4c6-f7b2-4ec5-88b8-ba7e391590b3
# 7   01eda7e7-7a37-41e7-910e-4ea8185d8ab8
# 8   6ebe3545-a08b-4ffd-a688-b9106352c832
# 9   7572804a-ed02-4584-9f56-3f732939e175
# 10  f0c1321e-fe9a-4c12-b27a-d31ab6147796
# 11  e82d7441-a676-4f2d-9b7f-d3e538c2d7e3
# 12  3db3e39e-4461-4e91-b969-c44088aaab0a
# 13  1318385d-efbd-4fa1-a73f-e59e7172d22c
# 14  a07814a3-fa63-4033-9b9c-45881be770e2
# 15  3cd32b8c-f3c3-4001-befb-47825e5fa506
#
#                                              imageURL  \
# 0   https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 1   https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 2   https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 3   https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 4   https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 5   https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 6   https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 7   https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 8   https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 9   https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 10  https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 11  https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 12  https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 13  https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 14  https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 15  https://d3t3ozftmdmh3i.cloudfront.net/producti...
#
#                                                  link  \
# 0   https://anchor.fm/david-ferrufino/episodes/des...
# 1   https://anchor.fm/david-ferrufino/episodes/Res...
# 2   https://anchor.fm/david-ferrufino/episodes/Rea...
# 3   https://anchor.fm/david-ferrufino/episodes/Pod...
# 4   https://anchor.fm/david-ferrufino/episodes/Ana...
# 5   https://anchor.fm/david-ferrufino/episodes/Pro...
# 6   https://anchor.fm/david-ferrufino/episodes/ep-...
# 7   https://anchor.fm/david-ferrufino/episodes/un-...
# 8   https://anchor.fm/david-ferrufino/episodes/Sec...
# 9   https://anchor.fm/david-ferrufino/episodes/sec...
# 10  https://anchor.fm/david-ferrufino/episodes/Pod...
# 11  https://anchor.fm/david-ferrufino/episodes/Sec...
# 12  https://anchor.fm/david-ferrufino/episodes/Fel...
# 13  https://anchor.fm/david-ferrufino/episodes/Pod...
# 14  https://anchor.fm/david-ferrufino/episodes/Rec...
# 15  https://anchor.fm/david-ferrufino/episodes/Hab...
#
#                           pubDate soundbite  \
# 0   Wed, 13 Oct 2021 23:50:00 GMT        []
# 1   Tue, 23 Nov 2021 13:32:27 GMT        []
# 2   Tue, 19 Oct 2021 22:14:02 GMT        []
# 3   Tue, 18 Jan 2022 00:00:00 GMT        []
# 4   Tue, 02 Nov 2021 15:35:00 GMT        []
# 5   Sun, 28 Nov 2021 03:07:41 GMT        []
# 6   Sun, 03 Jan 2021 17:03:47 GMT        []
# 7   Sat, 27 Nov 2021 17:54:38 GMT        []
# 8   Sat, 23 Oct 2021 15:34:02 GMT        []
# 9   Sat, 15 Jan 2022 18:10:00 GMT        []
# 10  Mon, 25 Oct 2021 22:07:14 GMT        []
# 11  Mon, 18 Oct 2021 22:14:10 GMT        []
# 12  Fri, 31 Dec 2021 21:11:11 GMT        []
# 13  Fri, 29 Oct 2021 23:25:33 GMT        []
# 14  Fri, 15 Oct 2021 21:10:27 GMT        []
# 15  Fri, 07 Jan 2022 00:00:00 GMT        []
#
#                                               summary transcript value
# 0   Hola a todos. En este episodio, David Mendoza ...         []  None
# 1   En este episodio, Fabricio Ponce nos trae la e...         []  None
# 2   En este episodio, Tito Valle y David Mendoza, ...         []  None
# 3   En este episodio, Fabricio Ponce nos actualiza...         []  None
# 4   Qué tal oyentes del podcast EL ANÁLISIS. En es...         []  None
# 5   <p>en este episodio, David Mendoza, Fabricio P...         []  None
# 6                                                 NaN         []  None
# 7   <p>en este episodio, el compañero Fabricio Pon...         []  None
# 8   En este episodio, Fabricio Ponce nos hace un e...         []  None
# 9   en este episodio, Fabricio Ponce nos habla de ...         []  None
# 10  En este episodio, Fabricio Ponce “como ya nos ...         []  None
# 11  Hoy, Fabricio Ponce nos trae los resultados de...         []  None
# 12  En este episodio un poco más informal, hablare...         []  None
# 13  En este episodio, Fabricio Ponce nos habla de ...         []  None
# 14  En este episodio, Fabricio ponse nos trae un e...         []  None
# 15  en este primer episodio del 2022 analizamos la...         []  None

# %%
def get_episodes(x):
    id = x['databaseId']
    df = pd.DataFrame(x['scraped']['episodes'])
    df['podcastId'] = id
    return df

# %%
episodes = df.apply(get_episodes, axis=1)

# %%
pd.concat(episodes.to_list())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pd.concat(episodes.to_list())
#
# File ~/anaconda3/envs/podcasts/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/podcasts/lib/python3.11/site-packages/pandas/core/reshape/concat.py:381, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     159 """
#     160 Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366 1   3   4
#     367 """
#     368 op = _Concatenator(
#     369     objs,
#     370     axis=axis,
#    (...)
#     378     sort=sort,
#     379 )
# --> 381 return op.get_result()
#
# File ~/anaconda3/envs/podcasts/lib/python3.11/site-packages/pandas/core/reshape/concat.py:616, in _Concatenator.get_result(self)
#     612             indexers[ax] = obj_labels.get_indexer(new_labels)
#     614     mgrs_indexers.append((obj._mgr, indexers))
# --> 616 new_data = concatenate_managers(
#     617     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     618 )
#     619 if not self.copy:
#     620     new_data._consolidate_inplace()
#
# File ~/anaconda3/envs/podcasts/lib/python3.11/site-packages/pandas/core/internals/concat.py:199, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     195     return _concatenate_array_managers(mgrs_indexers, axes, concat_axis, copy)
#     197 mgrs_indexers = _maybe_reindex_columns_na_proxy(axes, mgrs_indexers)
# --> 199 concat_plans = [
#     200     _get_mgr_concatenation_plan(mgr, indexers) for mgr, indexers in mgrs_indexers
#     201 ]
#     202 concat_plan = _combine_concat_plans(concat_plans, concat_axis)
#     203 blocks = []
#
# File ~/anaconda3/envs/podcasts/lib/python3.11/site-packages/pandas/core/internals/concat.py:200, in <listcomp>(.0)
#     195     return _concatenate_array_managers(mgrs_indexers, axes, concat_axis, copy)
#     197 mgrs_indexers = _maybe_reindex_columns_na_proxy(axes, mgrs_indexers)
#     199 concat_plans = [
# --> 200     _get_mgr_concatenation_plan(mgr, indexers) for mgr, indexers in mgrs_indexers
#     201 ]
#     202 concat_plan = _combine_concat_plans(concat_plans, concat_axis)
#     203 blocks = []
#
# File ~/anaconda3/envs/podcasts/lib/python3.11/site-packages/pandas/core/internals/concat.py:314, in _get_mgr_concatenation_plan(mgr, indexers)
#     311 assert placements.is_slice_like
#     312 assert blkno != -1
# --> 314 join_unit_indexers = indexers.copy()
#     316 shape_list = list(mgr_shape)
#     317 shape_list[0] = len(placements)
#
# KeyboardInterrupt:

# %%
episodes[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 episodes[0]
#
# NameError: name 'episodes' is not defined

# %%
podcasts.describe()
# Out:
#                  id
# count  2.500000e+05
# mean   2.831034e+06
# std    1.312297e+05
# min    2.603673e+06
# 25%    2.713973e+06
# 50%    2.830568e+06
# 75%    2.951848e+06
# max    3.048218e+06

# %%
value_counts = (podcasts.isna().sum() / podcasts.shape[0]).sort_values()

# %%
podcasts.drop(columns=value_counts[value_counts > 0.9].index, inplace=True)

# %%
podcasts.drop(columns=['type', 'funding'], inplace=True, errors='ignore')

# %%
podcasts.to_pickle('data/xaa_podcasts.pkl')

# %%
podcasts['explicit'] = podcasts['explicit'].astype(bool)

# %%
value_counts = (episodes.isna().sum() / episodes.shape[0]).sort_values()

# %%
value_counts
# Out:
# explicit       0.000000
# podcastId      0.000000
# title          0.000009
# enclosure      0.008669
# pubDate        0.008950
# duration       0.054645
# link           0.081812
# description    0.137879
# imageURL       0.170745
# guid           0.228511
# summary        0.365771
# author         0.490391
# subtitle       0.647667
# keywords       0.839837
# dtype: float64

# %%
episodes.drop(columns=value_counts[value_counts > 0.9].index, inplace=True)

# %%
episodes['explicit'] = episodes['explicit'].astype(bool)

# %%
episodes.drop(columns=['funding', 'transcript', 'soundbite'], inplace=True, errors='ignore')

# %%
from datetime import datetime
def timezone_map(x):
    try:
        x = " ".join(x.split(' ')[:4]) # remove timestamp, keep only date
        date_format = "%a, %d %b %Y"
        return datetime.strptime(x, date_format)
    except:
        return None

# %%
dates = episodes.pubDate.map(timezone_map)

# %%
episodes['pubDate'] = dates

# %%
episodes.to_pickle('data/xaa_episodes.pkl')
